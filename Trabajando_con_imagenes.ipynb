# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianJoa/Colaboratibe/blob/main/Trabajando_con_imagenes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Trabajando con imagenes**

# %%
import cv2
import matplotlib.pyplot as plt

path = "/content/drive/MyDrive/Colab Notebooks/img/Funny_Dog_S.jpg"
img = cv2.imread(path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2YUV_IYUV)
plt.imshow(img_rgb)
